# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_excel("Houston-security.xls",index_col='# Of Offenses')

# %%
del df['Beat']
del df['Premise']
del df['Block Range']
del df['Street Name']
del df['Type']
del df['Suffix']
del df['Date']

# %%
df
# Out:
#                Hour Offense Type
# # Of Offenses
# 1                12       Murder
# 1                 6       Murder
# 1                18       Murder
# 1                 3       Murder
# 1                23       Murder
# 1                 4       Murder
# 1                22       Murder
# 1                21       Murder
# 1                21       Murder
# 1                22       Murder
# 2                 0       Murder
# 1                22       Murder
# 1                19       Murder
# 2                16       Murder
# 2                12         Rape
# 1                 2         Rape
# 1                20         Rape
# 1                17         Rape
# 1                10         Rape
# 1                19         Rape
# 1                18         Rape
# 1                 0         Rape
# 1                18         Rape
# 1                 2         Rape
# 1                17         Rape
# 2                 4         Rape
# 1                20         Rape
# ...

# %%
figure(figsize(50,50))
df.hist(by=df['Offense Type'],bins = 24)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x2841a4d50>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x284afcb10>]], dtype=object)

# %% [markdown]
# Al vizualizar los datos en histogramas es posible concluir que el crimen no madruga y las calles son mas seguras en las horas de la mañana, entre las 4 y las 7.
